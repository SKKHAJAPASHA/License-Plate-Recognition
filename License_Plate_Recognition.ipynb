# %%
import zipfile
import os

def unzip_data(zip_file_path, extract_to):
    """Unzip the given zip file"""
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# Defineing paths
detection_zip_path = 'Licplatesdetection_train.zip'
recognition_zip_path = 'Licplatesrecognition_train.zip'
test_zip_path = 'test.zip'

# Createing directories to extract files
os.makedirs('detection_train', exist_ok=True)
os.makedirs('recognition_train', exist_ok=True)
os.makedirs('test', exist_ok=True)

# Unzip the data
unzip_data(detection_zip_path, 'detection_train')
unzip_data(recognition_zip_path, 'recognition_train')
unzip_data(test_zip_path, 'test')

# %%
import pandas as pd

# Loading license plate detection data
detection_data = pd.read_csv('Licplatesdetection_train.csv')
print(detection_data.head())
# Out:
#     img_id  ymin  xmin  ymax  xmax
# 0    1.jpg   276    94   326   169
# 1   10.jpg   311   395   344   444
# 2  100.jpg   406   263   450   434
# 3  101.jpg   283   363   315   494
# 4  102.jpg   139    42   280   222

# %%
import os
import pandas as pd
import cv2

def load_detection_data(detection_data, image_folder):
    images = []
    boxes = []

    for _, row in detection_data.iterrows():
        img_name = row['img_id']
        img_path = os.path.join(image_folder, img_name)

        # Checking if the file exists
        if not os.path.exists(img_path):
            print(f"Error: The file does not exist at {img_path}")
            continue  # Skip to the next iteration if the file does not exist
        
        # Attempt to load the image
        image = cv2.imread(img_path)
        
        if image is None:
            print(f"Warning: Could not load image at {img_path}. Check if the file is a valid image.")
            continue
        
        images.append(image)
        box = (
            int(row['xmin']), 
            int(row['ymin']), 
            int(row['xmax']), 
            int(row['ymax'])
        )
        boxes.append(box)

    return images, boxes

# Provideing the correct path to the folder containing detection images
detection_images_folder = r"C:\Users\globa\Downloads\License Plate Recognition\detection_train\license_plates_detection_train"

# Example usage: Loading detection data
# Ensure that detection_data variable is correctly defined as well
detection_images, detection_boxes = load_detection_data(detection_data, detection_images_folder)

# %%
# Loading license plate recognition data
recognition_data = pd.read_csv('Licplatesrecognition_train.csv')
print(recognition_data.head())
# Out:
#     img_id      text
# 0    0.jpg  117T3989
# 1    1.jpg  128T8086
# 2   10.jpg   94T3458
# 3  100.jpg  133T6719
# 4  101.jpg   68T5979

# %%
import os
import cv2
import pandas as pd

def load_recognition_data(recognition_data, image_folder):
    images = []
    labels = []
    
    for _, row in recognition_data.iterrows():
        img_id = row['img_id']  # Make sure `img_id` exists in your DataFrame
        img_path = os.path.join(image_folder, img_id)
        
        print(f"Attempting to load image from: {img_path}")
        
        # Read as grayscale for character recognition
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        
        if image is None:
            print(f"Error: Could not load image at {img_path}")
            continue  # Skip if the image can't be loaded
            
        images.append(image)
        labels.append(row['text'])  # Make `text` exists in my DataFrame
    
    return images, labels

# Defineing the folder with recognition images
recognition_images_folder = r"C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train"

# Loading my recognition data
# Ensureing that 'recognition_data' DataFrame is loaded beforehand
detection_images, detection_labels = load_recognition_data(recognition_data, recognition_images_folder)

# i may want to see quick outputs of the loaded images and labels
print(f"Loaded {len(detection_images)} images and {len(detection_labels)} labels.")
# Out:
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\0.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\1.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\10.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\100.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\101.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\102.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\103.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\104.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\105.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\106.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\107.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\108.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\109.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\11.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\110.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\111.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\112.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\113.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\114.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\115.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\116.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\117.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\118.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\119.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\12.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\120.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\121.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\122.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\123.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\124.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\125.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\126.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\127.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\128.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\129.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\13.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\130.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\131.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\132.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\133.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\134.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\135.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\136.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\137.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\138.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\139.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\14.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\140.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\141.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\142.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\143.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\144.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\145.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\146.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\147.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\148.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\149.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\150.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\151.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\152.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\153.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\154.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\155.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\156.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\157.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\158.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\159.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\16.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\160.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\161.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\162.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\163.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\164.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\165.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\166.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\167.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\168.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\169.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\17.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\170.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\171.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\172.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\173.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\174.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\175.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\176.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\177.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\178.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\179.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\18.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\180.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\181.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\182.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\183.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\184.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\185.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\186.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\187.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\188.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\189.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\19.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\190.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\191.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\192.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\193.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\194.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\195.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\196.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\197.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\198.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\199.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\2.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\20.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\200.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\201.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\202.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\203.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\204.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\205.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\206.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\207.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\208.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\209.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\21.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\210.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\211.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\212.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\213.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\214.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\215.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\216.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\217.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\218.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\219.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\22.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\220.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\221.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\222.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\223.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\224.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\225.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\226.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\227.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\228.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\229.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\23.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\230.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\231.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\232.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\233.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\234.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\235.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\236.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\237.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\238.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\239.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\24.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\240.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\241.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\242.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\243.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\244.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\245.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\246.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\247.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\248.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\249.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\25.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\250.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\251.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\252.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\253.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\254.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\255.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\256.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\257.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\258.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\259.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\26.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\260.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\261.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\262.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\263.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\264.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\265.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\266.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\267.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\268.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\27.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\270.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\271.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\272.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\273.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\274.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\275.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\276.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\277.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\278.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\279.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\28.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\280.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\281.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\282.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\283.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\284.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\285.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\286.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\287.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\288.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\289.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\29.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\290.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\291.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\292.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\293.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\294.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\295.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\296.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\297.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\298.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\299.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\3.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\30.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\300.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\301.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\302.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\303.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\304.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\305.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\306.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\307.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\308.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\309.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\31.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\310.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\311.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\312.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\313.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\314.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\315.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\316.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\317.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\318.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\319.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\32.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\320.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\321.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\322.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\323.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\324.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\325.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\326.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\327.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\328.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\329.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\33.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\330.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\331.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\332.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\333.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\334.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\335.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\336.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\337.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\338.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\339.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\34.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\340.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\341.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\342.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\343.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\344.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\345.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\346.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\347.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\348.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\349.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\35.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\350.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\351.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\352.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\353.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\354.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\355.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\356.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\357.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\358.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\359.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\36.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\360.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\361.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\362.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\363.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\364.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\365.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\366.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\367.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\368.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\369.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\37.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\370.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\371.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\372.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\373.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\374.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\375.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\376.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\377.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\378.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\379.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\38.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\380.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\381.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\382.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\384.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\385.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\386.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\387.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\388.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\389.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\39.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\390.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\391.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\392.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\393.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\394.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\395.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\396.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\397.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\398.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\399.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\4.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\40.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\400.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\401.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\402.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\403.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\404.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\405.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\406.jpg
# ...
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\816.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\817.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\818.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\819.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\82.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\820.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\821.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\822.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\823.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\824.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\825.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\826.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\827.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\828.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\829.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\83.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\830.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\831.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\832.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\833.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\834.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\835.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\836.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\837.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\838.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\839.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\84.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\840.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\841.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\842.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\843.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\844.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\845.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\846.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\847.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\848.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\849.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\85.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\850.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\851.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\852.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\853.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\854.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\855.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\856.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\857.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\858.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\859.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\86.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\860.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\861.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\862.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\863.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\864.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\865.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\866.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\867.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\868.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\869.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\87.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\870.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\871.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\872.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\873.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\874.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\875.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\876.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\877.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\878.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\879.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\88.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\880.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\881.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\882.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\883.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\884.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\885.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\886.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\887.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\888.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\889.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\89.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\890.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\891.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\892.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\893.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\894.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\895.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\896.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\897.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\898.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\899.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\9.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\90.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\900.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\901.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\902.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\903.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\904.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\905.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\906.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\907.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\908.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\91.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\910.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\92.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\93.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\94.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\95.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\96.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\97.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\98.jpg
# Attempting to load image from: C:\Users\globa\Downloads\License Plate Recognition\recognition_train\license_plates_recognition_train\99.jpg
# Loaded 900 images and 900 labels.

# %%
print(recognition_data.columns)
# Out:
# Index(['img_id', 'text'], dtype='object')

# %%
print(recognition_data['img_id'].unique())
# Out:
# ['0.jpg' '1.jpg' '10.jpg' '100.jpg' '101.jpg' '102.jpg' '103.jpg'
#  '104.jpg' '105.jpg' '106.jpg' '107.jpg' '108.jpg' '109.jpg' '11.jpg'
#  '110.jpg' '111.jpg' '112.jpg' '113.jpg' '114.jpg' '115.jpg' '116.jpg'
#  '117.jpg' '118.jpg' '119.jpg' '12.jpg' '120.jpg' '121.jpg' '122.jpg'
#  '123.jpg' '124.jpg' '125.jpg' '126.jpg' '127.jpg' '128.jpg' '129.jpg'
#  '13.jpg' '130.jpg' '131.jpg' '132.jpg' '133.jpg' '134.jpg' '135.jpg'
#  '136.jpg' '137.jpg' '138.jpg' '139.jpg' '14.jpg' '140.jpg' '141.jpg'
#  '142.jpg' '143.jpg' '144.jpg' '145.jpg' '146.jpg' '147.jpg' '148.jpg'
#  '149.jpg' '150.jpg' '151.jpg' '152.jpg' '153.jpg' '154.jpg' '155.jpg'
#  '156.jpg' '157.jpg' '158.jpg' '159.jpg' '16.jpg' '160.jpg' '161.jpg'
#  '162.jpg' '163.jpg' '164.jpg' '165.jpg' '166.jpg' '167.jpg' '168.jpg'
#  '169.jpg' '17.jpg' '170.jpg' '171.jpg' '172.jpg' '173.jpg' '174.jpg'
#  '175.jpg' '176.jpg' '177.jpg' '178.jpg' '179.jpg' '18.jpg' '180.jpg'
#  '181.jpg' '182.jpg' '183.jpg' '184.jpg' '185.jpg' '186.jpg' '187.jpg'
#  '188.jpg' '189.jpg' '19.jpg' '190.jpg' '191.jpg' '192.jpg' '193.jpg'
#  '194.jpg' '195.jpg' '196.jpg' '197.jpg' '198.jpg' '199.jpg' '2.jpg'
#  '20.jpg' '200.jpg' '201.jpg' '202.jpg' '203.jpg' '204.jpg' '205.jpg'
#  '206.jpg' '207.jpg' '208.jpg' '209.jpg' '21.jpg' '210.jpg' '211.jpg'
#  '212.jpg' '213.jpg' '214.jpg' '215.jpg' '216.jpg' '217.jpg' '218.jpg'
#  '219.jpg' '22.jpg' '220.jpg' '221.jpg' '222.jpg' '223.jpg' '224.jpg'
#  '225.jpg' '226.jpg' '227.jpg' '228.jpg' '229.jpg' '23.jpg' '230.jpg'
#  '231.jpg' '232.jpg' '233.jpg' '234.jpg' '235.jpg' '236.jpg' '237.jpg'
#  '238.jpg' '239.jpg' '24.jpg' '240.jpg' '241.jpg' '242.jpg' '243.jpg'
#  '244.jpg' '245.jpg' '246.jpg' '247.jpg' '248.jpg' '249.jpg' '25.jpg'
#  '250.jpg' '251.jpg' '252.jpg' '253.jpg' '254.jpg' '255.jpg' '256.jpg'
#  '257.jpg' '258.jpg' '259.jpg' '26.jpg' '260.jpg' '261.jpg' '262.jpg'
#  '263.jpg' '264.jpg' '265.jpg' '266.jpg' '267.jpg' '268.jpg' '27.jpg'
#  '270.jpg' '271.jpg' '272.jpg' '273.jpg' '274.jpg' '275.jpg' '276.jpg'
#  '277.jpg' '278.jpg' '279.jpg' '28.jpg' '280.jpg' '281.jpg' '282.jpg'
#  '283.jpg' '284.jpg' '285.jpg' '286.jpg' '287.jpg' '288.jpg' '289.jpg'
#  '29.jpg' '290.jpg' '291.jpg' '292.jpg' '293.jpg' '294.jpg' '295.jpg'
#  '296.jpg' '297.jpg' '298.jpg' '299.jpg' '3.jpg' '30.jpg' '300.jpg'
#  '301.jpg' '302.jpg' '303.jpg' '304.jpg' '305.jpg' '306.jpg' '307.jpg'
#  '308.jpg' '309.jpg' '31.jpg' '310.jpg' '311.jpg' '312.jpg' '313.jpg'
#  '314.jpg' '315.jpg' '316.jpg' '317.jpg' '318.jpg' '319.jpg' '32.jpg'
#  '320.jpg' '321.jpg' '322.jpg' '323.jpg' '324.jpg' '325.jpg' '326.jpg'
#  '327.jpg' '328.jpg' '329.jpg' '33.jpg' '330.jpg' '331.jpg' '332.jpg'
#  '333.jpg' '334.jpg' '335.jpg' '336.jpg' '337.jpg' '338.jpg' '339.jpg'
#  '34.jpg' '340.jpg' '341.jpg' '342.jpg' '343.jpg' '344.jpg' '345.jpg'
#  '346.jpg' '347.jpg' '348.jpg' '349.jpg' '35.jpg' '350.jpg' '351.jpg'
#  '352.jpg' '353.jpg' '354.jpg' '355.jpg' '356.jpg' '357.jpg' '358.jpg'
#  '359.jpg' '36.jpg' '360.jpg' '361.jpg' '362.jpg' '363.jpg' '364.jpg'
#  '365.jpg' '366.jpg' '367.jpg' '368.jpg' '369.jpg' '37.jpg' '370.jpg'
#  '371.jpg' '372.jpg' '373.jpg' '374.jpg' '375.jpg' '376.jpg' '377.jpg'
#  '378.jpg' '379.jpg' '38.jpg' '380.jpg' '381.jpg' '382.jpg' '384.jpg'
#  '385.jpg' '386.jpg' '387.jpg' '388.jpg' '389.jpg' '39.jpg' '390.jpg'
#  '391.jpg' '392.jpg' '393.jpg' '394.jpg' '395.jpg' '396.jpg' '397.jpg'
#  '398.jpg' '399.jpg' '4.jpg' '40.jpg' '400.jpg' '401.jpg' '402.jpg'
#  '403.jpg' '404.jpg' '405.jpg' '406.jpg' '407.jpg' '408.jpg' '409.jpg'
#  '41.jpg' '410.jpg' '411.jpg' '412.jpg' '413.jpg' '414.jpg' '415.jpg'
#  '416.jpg' '417.jpg' '418.jpg' '419.jpg' '42.jpg' '421.jpg' '422.jpg'
#  '423.jpg' '424.jpg' '425.jpg' '426.jpg' '427.jpg' '428.jpg' '429.jpg'
#  '43.jpg' '430.jpg' '431.jpg' '432.jpg' '433.jpg' '434.jpg' '435.jpg'
#  '436.jpg' '437.jpg' '438.jpg' '44.jpg' '440.jpg' '441.jpg' '442.jpg'
#  '443.jpg' '444.jpg' '445.jpg' '446.jpg' '447.jpg' '448.jpg' '449.jpg'
#  '45.jpg' '450.jpg' '451.jpg' '452.jpg' '453.jpg' '454.jpg' '455.jpg'
#  '456.jpg' '457.jpg' '458.jpg' '459.jpg' '46.jpg' '460.jpg' '461.jpg'
#  '462.jpg' '463.jpg' '464.jpg' '465.jpg' '466.jpg' '468.jpg' '469.jpg'
#  '47.jpg' '470.jpg' '471.jpg' '472.jpg' '473.jpg' '474.jpg' '475.jpg'
#  '476.jpg' '477.jpg' '478.jpg' '479.jpg' '48.jpg' '480.jpg' '481.jpg'
#  '482.jpg' '483.jpg' '484.jpg' '485.jpg' '486.jpg' '487.jpg' '488.jpg'
#  '489.jpg' '49.jpg' '490.jpg' '491.jpg' '492.jpg' '493.jpg' '494.jpg'
#  '495.jpg' '496.jpg' '497.jpg' '498.jpg' '499.jpg' '5.jpg' '50.jpg'
#  '500.jpg' '501.jpg' '502.jpg' '503.jpg' '504.jpg' '505.jpg' '506.jpg'
#  '507.jpg' '508.jpg' '509.jpg' '51.jpg' '510.jpg' '511.jpg' '512.jpg'
#  '513.jpg' '514.jpg' '515.jpg' '516.jpg' '517.jpg' '518.jpg' '519.jpg'
#  '52.jpg' '520.jpg' '521.jpg' '522.jpg' '523.jpg' '524.jpg' '525.jpg'
#  '526.jpg' '527.jpg' '528.jpg' '529.jpg' '53.jpg' '530.jpg' '531.jpg'
#  '532.jpg' '533.jpg' '534.jpg' '535.jpg' '536.jpg' '537.jpg' '539.jpg'
#  '54.jpg' '540.jpg' '541.jpg' '542.jpg' '543.jpg' '544.jpg' '545.jpg'
#  '546.jpg' '547.jpg' '548.jpg' '549.jpg' '55.jpg' '550.jpg' '551.jpg'
#  '552.jpg' '553.jpg' '554.jpg' '555.jpg' '557.jpg' '558.jpg' '559.jpg'
#  '56.jpg' '560.jpg' '561.jpg' '562.jpg' '563.jpg' '564.jpg' '565.jpg'
#  '566.jpg' '567.jpg' '569.jpg' '57.jpg' '570.jpg' '571.jpg' '572.jpg'
#  '573.jpg' '574.jpg' '575.jpg' '576.jpg' '577.jpg' '578.jpg' '579.jpg'
#  '58.jpg' '580.jpg' '581.jpg' '582.jpg' '583.jpg' '584.jpg' '585.jpg'
#  '586.jpg' '587.jpg' '588.jpg' '589.jpg' '59.jpg' '590.jpg' '591.jpg'
#  '592.jpg' '593.jpg' '594.jpg' '595.jpg' '596.jpg' '597.jpg' '598.jpg'
#  '599.jpg' '6.jpg' '60.jpg' '600.jpg' '601.jpg' '602.jpg' '603.jpg'
#  '604.jpg' '605.jpg' '606.jpg' '607.jpg' '608.jpg' '609.jpg' '61.jpg'
#  '610.jpg' '611.jpg' '612.jpg' '613.jpg' '614.jpg' '615.jpg' '616.jpg'
#  '617.jpg' '618.jpg' '619.jpg' '62.jpg' '620.jpg' '621.jpg' '622.jpg'
#  '623.jpg' '624.jpg' '625.jpg' '626.jpg' '627.jpg' '628.jpg' '629.jpg'
#  '63.jpg' '630.jpg' '631.jpg' '632.jpg' '633.jpg' '634.jpg' '635.jpg'
#  '636.jpg' '637.jpg' '638.jpg' '639.jpg' '64.jpg' '640.jpg' '641.jpg'
#  '642.jpg' '643.jpg' '644.jpg' '645.jpg' '646.jpg' '647.jpg' '648.jpg'
#  '649.jpg' '65.jpg' '650.jpg' '651.jpg' '652.jpg' '653.jpg' '654.jpg'
#  '655.jpg' '656.jpg' '657.jpg' '658.jpg' '659.jpg' '66.jpg' '660.jpg'
#  '661.jpg' '662.jpg' '663.jpg' '664.jpg' '665.jpg' '666.jpg' '667.jpg'
#  '668.jpg' '669.jpg' '67.jpg' '670.jpg' '671.jpg' '672.jpg' '673.jpg'
#  '674.jpg' '675.jpg' '676.jpg' '677.jpg' '678.jpg' '679.jpg' '68.jpg'
#  '680.jpg' '681.jpg' '682.jpg' '683.jpg' '684.jpg' '685.jpg' '686.jpg'
#  '687.jpg' '688.jpg' '689.jpg' '69.jpg' '690.jpg' '691.jpg' '692.jpg'
#  '693.jpg' '694.jpg' '695.jpg' '696.jpg' '697.jpg' '698.jpg' '699.jpg'
#  '7.jpg' '70.jpg' '700.jpg' '701.jpg' '702.jpg' '703.jpg' '704.jpg'
#  '705.jpg' '706.jpg' '707.jpg' '708.jpg' '709.jpg' '71.jpg' '710.jpg'
#  '711.jpg' '712.jpg' '713.jpg' '714.jpg' '715.jpg' '716.jpg' '717.jpg'
#  '718.jpg' '719.jpg' '72.jpg' '720.jpg' '721.jpg' '722.jpg' '723.jpg'
#  '724.jpg' '725.jpg' '726.jpg' '727.jpg' '728.jpg' '729.jpg' '73.jpg'
#  '730.jpg' '731.jpg' '732.jpg' '733.jpg' '735.jpg' '736.jpg' '737.jpg'
#  '738.jpg' '739.jpg' '74.jpg' '740.jpg' '741.jpg' '742.jpg' '743.jpg'
#  '744.jpg' '745.jpg' '746.jpg' '747.jpg' '748.jpg' '749.jpg' '75.jpg'
#  '750.jpg' '751.jpg' '752.jpg' '753.jpg' '754.jpg' '755.jpg' '756.jpg'
#  '757.jpg' '758.jpg' '759.jpg' '76.jpg' '760.jpg' '761.jpg' '762.jpg'
#  '763.jpg' '764.jpg' '765.jpg' '766.jpg' '767.jpg' '768.jpg' '769.jpg'
#  '77.jpg' '770.jpg' '771.jpg' '772.jpg' '773.jpg' '774.jpg' '775.jpg'
#  '776.jpg' '777.jpg' '778.jpg' '779.jpg' '78.jpg' '780.jpg' '781.jpg'
#  '782.jpg' '783.jpg' '784.jpg' '785.jpg' '786.jpg' '787.jpg' '788.jpg'
#  '789.jpg' '79.jpg' '790.jpg' '791.jpg' '792.jpg' '793.jpg' '794.jpg'
#  '795.jpg' '796.jpg' '797.jpg' '798.jpg' '799.jpg' '8.jpg' '80.jpg'
#  '800.jpg' '801.jpg' '802.jpg' '803.jpg' '804.jpg' '805.jpg' '806.jpg'
#  '807.jpg' '808.jpg' '809.jpg' '81.jpg' '810.jpg' '811.jpg' '812.jpg'
#  '813.jpg' '814.jpg' '815.jpg' '816.jpg' '817.jpg' '818.jpg' '819.jpg'
#  '82.jpg' '820.jpg' '821.jpg' '822.jpg' '823.jpg' '824.jpg' '825.jpg'
#  '826.jpg' '827.jpg' '828.jpg' '829.jpg' '83.jpg' '830.jpg' '831.jpg'
#  '832.jpg' '833.jpg' '834.jpg' '835.jpg' '836.jpg' '837.jpg' '838.jpg'
#  '839.jpg' '84.jpg' '840.jpg' '841.jpg' '842.jpg' '843.jpg' '844.jpg'
#  '845.jpg' '846.jpg' '847.jpg' '848.jpg' '849.jpg' '85.jpg' '850.jpg'
#  '851.jpg' '852.jpg' '853.jpg' '854.jpg' '855.jpg' '856.jpg' '857.jpg'
#  '858.jpg' '859.jpg' '86.jpg' '860.jpg' '861.jpg' '862.jpg' '863.jpg'
#  '864.jpg' '865.jpg' '866.jpg' '867.jpg' '868.jpg' '869.jpg' '87.jpg'
#  '870.jpg' '871.jpg' '872.jpg' '873.jpg' '874.jpg' '875.jpg' '876.jpg'
#  '877.jpg' '878.jpg' '879.jpg' '88.jpg' '880.jpg' '881.jpg' '882.jpg'
#  '883.jpg' '884.jpg' '885.jpg' '886.jpg' '887.jpg' '888.jpg' '889.jpg'
#  '89.jpg' '890.jpg' '891.jpg' '892.jpg' '893.jpg' '894.jpg' '895.jpg'
#  '896.jpg' '897.jpg' '898.jpg' '899.jpg' '9.jpg' '90.jpg' '900.jpg'
#  '901.jpg' '902.jpg' '903.jpg' '904.jpg' '905.jpg' '906.jpg' '907.jpg'
#  '908.jpg' '91.jpg' '910.jpg' '92.jpg' '93.jpg' '94.jpg' '95.jpg' '96.jpg'
#  '97.jpg' '98.jpg' '99.jpg']

# %%
import numpy as np

def preprocess_detection(images):
    processed_images = []
    
    for image in images:
        # Checking if image is not None before proceeding
        if image is not None:
            resized_image = cv2.resize(image, (416, 416))  # Resize for detection model
            processed_images.append(resized_image)
        else:
            print("Skipping an image because it is None.")
    
    return np.array(processed_images)

# Assuming detection_images is the output from load_detection_data
X_detection = preprocess_detection(detection_images)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
def preprocess_recognition(images, labels):
    processed_images = []
    for image in images:
        image = cv2.resize(image, (64, 128))  # Resize for recognition model
        processed_images.append(image)
    
    processed_images = np.array(processed_images)
    processed_images = np.expand_dims(processed_images, axis=-1)  # Adding channel dimension

    # Encodeing labels
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(labels)
    one_hot_labels = to_categorical(encoded_labels)
    return processed_images, one_hot_labels, label_encoder

# Preprocessing the recognition data
X_recognition, y_recognition, label_encoder = preprocess_recognition(recognition_images, recognition_labels)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.preprocessing import LabelEncoder
# ----> 2 from tensorflow.keras.utils import to_categorical
#       3 def preprocess_recognition(images, labels):
#       4     processed_images = []
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\globa\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

def create_detection_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(416, 416, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(4, activation='linear'))  # Output: xmin, ymin, xmax, ymax
    return model

# Create and compileing model
detection_model = create_detection_model()
detection_model.compile(optimizer='adam', loss='mse')  # Useing appropriate loss for bounding boxes

# Training detection model (my own data split and validation if needed)
detection_model.fit(X_detection, np.array(detection_boxes), epochs=10, batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
#       4 def create_detection_model():
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\globa\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
def create_recognition_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 128, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(len(label_encoder.classes_), activation='softmax'))  # Output: character classes
    return model

# Createing and compile model
recognition_model = create_recognition_model()
recognition_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Training recognition model
recognition_model.fit(X_recognition, y_recognition, epochs=10, batch_size=16)

# %%
# Loading the test images - assuming test.zip contains images without labels
test_image_paths = os.listdir('test')

def preprocess_test_images(test_image_paths):
    test_images = []
    
    for img_name in test_image_paths:
        img_path = os.path.join('test', img_name)
        image = cv2.imread(img_path)
        image = cv2.resize(image, (416, 416))  # Resize like detection model
        test_images.append(image)
    
    return np.array(test_images)

# Loading and preprocessing test images
X_test = preprocess_test_images(test_image_paths)

# Detection predictions on test images
test_detections = detection_model.predict(X_test)

# For each detection, i crop the images and recognize
submission_data = []

for idx, img_name in enumerate(test_image_paths):
    img = X_test[idx]
    boxes = test_detections[idx]
    
    # Assuming boxes are in the format: [x_min, y_min, x_max, y_max]
    for box in boxes:  
        x_min, y_min, x_max, y_max = map(int, box)
        cropped_plate = img[y_min:y_max, x_min:x_max]
        cropped_plate = cv2.resize(cropped_plate, (64, 128))  # Resize for recognition
        cropped_plate = np.expand_dims(cropped_plate, axis=-1)  # Adding channel dimension
        
        # Recognizeing characters
        predicted = recognition_model.predict(np.array([cropped_plate]))
        predicted_label = label_encoder.inverse_transform([np.argmax(predicted)])
        submission_data.append({'image_name': img_name, 'predicted_label': predicted_label[0]})

# Saveing submission file
submission_df = pd.DataFrame(submission_data)
submission_df.to_csv('sample_submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 16
#      13     return np.array(test_images)
#      15 # Load and preprocess test images
# ---> 16 X_test = preprocess_test_images(test_image_paths)
#      18 # Detection predictions on test images
#      19 test_detections = detection_model.predict(X_test)
#
# Cell In[27], line 10, in preprocess_test_images(test_image_paths)
#       8     img_path = os.path.join('test', img_name)
#       9     image = cv2.imread(img_path)
# ---> 10     image = cv2.resize(image, (416, 416))  # Resize like detection model
#      11     test_images.append(image)
#      13 return np.array(test_images)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
if image is None:
    print(f"Image not found: {img_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 if image is None:
#       2     print(f"Image not found: {img_path}")
#
# NameError: name 'image' is not defined
